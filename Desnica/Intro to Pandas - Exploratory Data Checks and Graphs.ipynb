# %%
# import pandas and give alias "pd"
import pandas as pd

#used for plotting graphs
# %matplotlib inline

# %%
#product.csv is no delimited
#need to define seperator using sep function
#need to define date column using parse_dates function
        #parse_dates doesn't always work in all scenarios
        #might need another way to explicitly modify the date type
df=pd.read_csv('product.csv',sep='\t',parse_dates=['ModifiedDate'])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#how many rows and columns
df.shape
# Out:
# (504, 25)

# %%
#column names
df.columns
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode',
#        'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
#first 5 rows of data set by default
df.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0   NaN              1000           750           0.0
# 1                  0   NaN              1000           750           0.0
# 2                  0   NaN               800           600           0.0
# 3                  0   NaN               800           600           0.0
# 4                  0   NaN               800           600           0.0
#
#    ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 0        0.0  ...         NaN   NaN   NaN                   NaN
# ...

# %%
#last 5 rows by default
df.tail()
# Out:
#      ProductID                Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 499        995   ML Bottom Bracket       BB-8107         1                  1
# 500        996   HL Bottom Bracket       BB-9108         1                  1
# 501        997  Road-750 Black, 44    BK-R19B-44         1                  1
# 502        998  Road-750 Black, 48    BK-R19B-48         1                  1
# 503        999  Road-750 Black, 52    BK-R19B-52         1                  1
#
#      Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 499    NaN               500           375       44.9506     101.24  ...
# 500    NaN               500           375       53.9416     121.49  ...
# 501  Black               100            75      343.6496     539.99  ...
# 502  Black               100            75      343.6496     539.99  ...
# 503  Black               100            75      343.6496     539.99  ...
#
# ...

# %%
#number of rows returned can be selected
df.head(10)
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381         0
# 1          2           Bearing Ball       BA-8327         0
# 2          3        BB Ball Bearing       BE-2349         1
# 3          4  Headset Ball Bearings       BE-2908         0
# 4        316                  Blade       BL-2036         1
# 5        317            LL Crankarm       CA-5965         0
# 6        318            ML Crankarm       CA-6738         0
# 7        319            HL Crankarm       CA-7457         0
# 8        320        Chainring Bolts       CB-2903         0
# 9        321          Chainring Nut       CN-6137         0
#
#    FinishedGoodsFlag   Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  0     NaN              1000           750           0.0
# 1                  0     NaN              1000           750           0.0
# 2                  0     NaN               800           600           0.0
# ...

# %%
#range index info
df.index
# Out:
# RangeIndex(start=0, stop=504, step=1)

# %%
#random sample (by default 1 row)
df.sample()
# Out:
#      ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 196        524  HL Spindle/Axle       SD-9872         0                  0
#
#     Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 196   NaN               500           375           0.0        0.0  ...
#
#     ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 196         NaN   NaN   NaN                   NaN             NaN
#
#            SellStartDate SellEndDate DiscontinuedDate  \
# 196  2008-04-30 00:00:00         NaN              NaN
#
#                                     rowguid                   ModifiedDate
# 196  {6CE0661D-BA1F-4012-B785-55165B3B241A}  2014-02-08 10:01:36.827000000
#
# [1 rows x 25 columns]

# %%
#random sample of 3 records
df.sample(3)
# Out:
#      ProductID                     Name ProductNumber  MakeFlag  \
# 375        871     Mountain Bottle Cage       BC-M005         0
# 469        965  Touring-3000 Yellow, 62    BK-T18Y-62         1
# 315        811       LL Road Handlebars       HB-R504         1
#
#      FinishedGoodsFlag   Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 375                  1     NaN                 4             3        3.7363
# 469                  1  Yellow               100            75      461.4448
# 315                  1     NaN               500           375       19.7758
#
#      ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 375       9.99  ...          M    NaN   NaN                  28.0
# 469     742.35  ...          T     L     U                    3.0
# 315      44.54  ...          R     L    NaN                   4.0
#
#      ProductModelID        SellStartDate SellEndDate DiscontinuedDate  \
# ...

# %%
#values of a column (compressed)
df['ProductNumber']
# Out:
# 0         AR-5381
# 1         BA-8327
# 2         BE-2349
# 3         BE-2908
# 4         BL-2036
#           ...
# 499       BB-8107
# 500       BB-9108
# 501    BK-R19B-44
# 502    BK-R19B-48
# 503    BK-R19B-52
# Name: ProductNumber, Length: 504, dtype: object

# %%
#showing type of the column
type(df['ProductNumber'])
# Out:
# pandas.core.series.Series

# %%
# kind of the same as df['ProductNumber'] but we can't use the "." method when the column name has a space in it
#good fo column names to not have a space
df.ProductNumber
# Out:
# 0         AR-5381
# 1         BA-8327
# 2         BE-2349
# 3         BE-2908
# 4         BL-2036
#           ...
# 499       BB-8107
# 500       BB-9108
# 501    BK-R19B-44
# 502    BK-R19B-48
# 503    BK-R19B-52
# Name: ProductNumber, Length: 504, dtype: object

# %%
#can get shape of series (will tell number of rows)
df['ProductNumber'].shape
# Out:
# (504,)

# %%
#general info (missing values and data types of columns)
#default data type is object when python can't determine actual datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductID              504 non-null    int64
#  1   Name                   504 non-null    object
#  2   ProductNumber          504 non-null    object
#  3   MakeFlag               504 non-null    int64
#  4   FinishedGoodsFlag      504 non-null    int64
#  5   Color                  256 non-null    object
#  6   SafetyStockLevel       504 non-null    int64
#  7   ReorderPoint           504 non-null    int64
#  8   StandardCost           504 non-null    float64
#  9   ListPrice              504 non-null    float64
#  10  Size                   211 non-null    object
#  11  SizeUnitMeasureCode    176 non-null    object
#  12  WeightUnitMeasureCode  205 non-null    object
#  13  Weight                 205 non-null    float64
# ...

# %%
#if theres no null values then false, if there is a missing or null value then true
df.isnull()
# Out:
#      ProductID   Name  ProductNumber  MakeFlag  FinishedGoodsFlag  Color  \
# 0        False  False          False     False              False   True
# 1        False  False          False     False              False   True
# 2        False  False          False     False              False   True
# 3        False  False          False     False              False   True
# 4        False  False          False     False              False   True
# ..         ...    ...            ...       ...                ...    ...
# 499      False  False          False     False              False   True
# 500      False  False          False     False              False   True
# 501      False  False          False     False              False  False
# 502      False  False          False     False              False  False
# 503      False  False          False     False              False  False
#
#      SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# ...

# %%
#chaining isnull and sum methods
#to return number of null values in each column
df.isnull().sum()
# Out:
# ProductID                  0
# Name                       0
# ProductNumber              0
# MakeFlag                   0
# FinishedGoodsFlag          0
# Color                    248
# SafetyStockLevel           0
# ReorderPoint               0
# StandardCost               0
# ListPrice                  0
# Size                     293
# SizeUnitMeasureCode      328
# WeightUnitMeasureCode    299
# Weight                   299
# DaysToManufacture          0
# ProductLine              226
# Class                    257
# Style                    293
# ProductSubcategoryID     209
# ProductModelID           209
# SellStartDate              0
# SellEndDate              406
# DiscontinuedDate         504
# rowguid                    0
# ModifiedDate               0
# dtype: int64

# %%
#general statistical definitions
df.describe()
# Out:
#         ProductID    MakeFlag  FinishedGoodsFlag  SafetyStockLevel  \
# count  504.000000  504.000000         504.000000        504.000000
# mean   673.039683    0.474206           0.585317        535.150794
# std    229.373142    0.499830           0.493157        374.112954
# min      1.000000    0.000000           0.000000          4.000000
# 25%    447.750000    0.000000           0.000000        100.000000
# 50%    747.500000    0.000000           1.000000        500.000000
# 75%    873.250000    1.000000           1.000000       1000.000000
# max    999.000000    1.000000           1.000000       1000.000000
#
#        ReorderPoint  StandardCost    ListPrice       Weight  \
# count    504.000000    504.000000   504.000000   205.000000
# mean     401.363095    258.602961   438.666250    74.069220
# std      280.584715    461.632808   773.602843   182.166588
# min        3.000000      0.000000     0.000000     2.120000
# ...

# %%
#using Weight Is Null Mask to show only rows where the Weigh Column value is Null
df[df.Weight.isnull()].Weight
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 438   NaN
# 445   NaN
# 450   NaN
# 451   NaN
# 456   NaN
# Name: Weight, Length: 299, dtype: float64

# %%
#Number of unique values in the Name column
df.Name.nunique()
# Out:
# 504

# %%
#number of unique values for each column in df
df.nunique()
# Out:
# ProductID                504
# Name                     504
# ProductNumber            504
# MakeFlag                   2
# FinishedGoodsFlag          2
# Color                      9
# SafetyStockLevel           6
# ReorderPoint               6
# StandardCost             114
# ListPrice                103
# Size                      18
# SizeUnitMeasureCode        1
# WeightUnitMeasureCode      2
# Weight                   127
# DaysToManufacture          4
# ProductLine                4
# Class                      3
# Style                      3
# ProductSubcategoryID      37
# ProductModelID           119
# SellStartDate              4
# SellEndDate                2
# DiscontinuedDate           0
# rowguid                  504
# ModifiedDate               2
# dtype: int64

# %%
#list of unique values in the Color column
df.Color.unique()
# Out:
# array([nan, 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
#True/False of whether Color is in the list
df.Color.isin(['Red','White','Blue','Yellow'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 499    False
# 500    False
# 501    False
# 502    False
# 503    False
# Name: Color, Length: 504, dtype: bool

# %%
#creating new dataframe where we have subset of of records where Color is within the listed colors
df_color=df[df.Color.isin(['Red','White','Blue','Yellow'])]

df_color
# Out:
#      ProductID                     Name ProductNumber  MakeFlag  \
# 210        706  HL Road Frame - Red, 58    FR-R92R-58         1
# 211        707    Sport-100 Helmet, Red     HL-U509-R         0
# 213        709   Mountain Bike Socks, M     SO-B909-M         0
# 214        710   Mountain Bike Socks, L     SO-B909-L         0
# 215        711   Sport-100 Helmet, Blue     HL-U509-B         0
# ..         ...                      ...           ...       ...
# 478        974    Road-350-W Yellow, 42    BK-R79Y-42         1
# 479        975    Road-350-W Yellow, 44    BK-R79Y-44         1
# 480        976    Road-350-W Yellow, 48    BK-R79Y-48         1
# 482        978    Touring-3000 Blue, 44    BK-T18U-44         1
# 483        979    Touring-3000 Blue, 50    BK-T18U-50         1
#
#      FinishedGoodsFlag   Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 210                  1     Red               500           375     1059.3100
# ...

# %%
#checking the new data frame
df_color.Color.unique()
# Out:
# array(['Red', 'White', 'Blue', 'Yellow'], dtype=object)

# %%
#find min and max of the weight column
df.Weight.min(),df.Weight.max()
# Out:
# (2.12, 1050.0)

# %%
#Create a subset data frame where we're restricting weight
df_weight=df[df.Weight<50]
#return new dataframe
df_weight
# Out:
#      ProductID                       Name ProductNumber  MakeFlag  \
# 209        680  HL Road Frame - Black, 58    FR-R92B-58         1
# 210        706    HL Road Frame - Red, 58    FR-R92R-58         1
# 221        717    HL Road Frame - Red, 62    FR-R92R-62         1
# 222        718    HL Road Frame - Red, 44    FR-R92R-44         1
# 223        719    HL Road Frame - Red, 48    FR-R92R-48         1
# ..         ...                        ...           ...       ...
# 496        992     Mountain-500 Black, 48    BK-M18B-48         1
# 497        993     Mountain-500 Black, 52    BK-M18B-52         1
# 501        997         Road-750 Black, 44    BK-R19B-44         1
# 502        998         Road-750 Black, 48    BK-R19B-48         1
# 503        999         Road-750 Black, 52    BK-R19B-52         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 209                  1  Black               500           375     1059.3100
# ...

# %%
#where weight in <50 we can see the new min an max
df_weight.Weight.min(),df_weight.Weight.max()
# Out:
# (2.12, 30.0)

# %%
#checking further information of range of weights
df.Weight.describe()
# Out:
# count     205.000000
# mean       74.069220
# std       182.166588
# min         2.120000
# 25%         2.880000
# 50%        17.900000
# 75%        27.350000
# max      1050.000000
# Name: Weight, dtype: float64

# %%
#we can see the jump in values using these quick filter functions 
df[df.Weight>100].Weight
# Out:
# 179     435.0
# 180     450.0
# 181     400.0
# 182     445.0
# 183     450.0
# 184     400.0
# 185     460.0
# 322     900.0
# 323     850.0
# 324     650.0
# 330    1050.0
# 331    1000.0
# 332     890.0
# 398     215.0
# 411     317.0
# 439     218.0
# 440     215.0
# 441     185.0
# 442     189.0
# 443     168.0
# 444     149.0
# 452     317.0
# 453     600.0
# 454     635.0
# 455     575.0
# 498     223.0
# 499     168.0
# 500     170.0
# Name: Weight, dtype: float64

# %%
# further information from the Color column there are 9 colours but how can we see the frequency of colurs
df.Color.nunique()
# Out:
# 9

# %%
#don't forget to check how many null values there are 
df.Color.isnull().sum()
# Out:
# 248

# %%
#use value counts to see the number of each colour
#doesn't show the null values
df.Color.value_counts()
# Out:
# Black           93
# Silver          43
# Red             38
# Yellow          36
# Blue            26
# Multi            8
# Silver/Black     7
# White            4
# Grey             1
# Name: Color, dtype: int64

# %%
#finding the data types
df.dtypes
# Out:
# ProductID                  int64
# Name                      object
# ProductNumber             object
# MakeFlag                   int64
# FinishedGoodsFlag          int64
# Color                     object
# SafetyStockLevel           int64
# ReorderPoint               int64
# StandardCost             float64
# ListPrice                float64
# Size                      object
# SizeUnitMeasureCode       object
# WeightUnitMeasureCode     object
# Weight                   float64
# DaysToManufacture          int64
# ProductLine               object
# Class                     object
# Style                     object
# ProductSubcategoryID     float64
# ProductModelID           float64
# SellStartDate             object
# SellEndDate               object
# DiscontinuedDate         float64
# rowguid                   object
# ModifiedDate              object
# dtype: object

# %%
#number of nulls in Class column
df.Class.isnull().sum()
# Out:
# 257

# %%
#Categorical variables

# %%
#Name of the products where weight is greater than 500
df[df.Weight>500].Name
# Out:
# 322    LL Road Front Wheel
# 323    ML Road Front Wheel
# 324    HL Road Front Wheel
# 330     LL Road Rear Wheel
# 331     ML Road Rear Wheel
# 332     HL Road Rear Wheel
# 453            LL Crankset
# 454            ML Crankset
# 455            HL Crankset
# Name: Name, dtype: object

# %%
#Another random query
#Note you can't use shift tab tab on value counts method here
df[df.Weight>300].Color.value_counts()
# Out:
# Black     9
# Silver    2
# Name: Color, dtype: int64

# %%
#but if we save the first chain as a variable
tmp=df[df.Weight>300].Color

# %%
#and then use value counts
#then we can see the shift tab tab options
#'False' not 'false'
tmp.value_counts(dropna=False)
# Out:
# Black     9
# NaN       7
# Silver    2
# Name: Color, dtype: int64

# %%
#group by function
#mean weight grouped by Color
df.groupby('Color')['Weight'].mean()
# Out:
# Color
# Black           123.021250
# Blue             17.610909
# Grey                   NaN
# Multi                  NaN
# Red              10.173784
# Silver           40.579412
# Silver/Black    187.333333
# White                  NaN
# Yellow           13.820625
# Name: Weight, dtype: float64

# %%
#If we know the data set then we know what intuitive group by's would be necessary
#column that we are grouping by can be called with or without the use of square brackets 
#but the used column has to be in square brackets
df.groupby(['Class'])['Weight'].min()
# Out:
# Class
# H     2.12
# L     2.32
# M     2.18
# Name: Weight, dtype: float64

# %%
#Describing weight - grouped by Color
df.groupby(['Color'])['Weight'].describe()
# Out:
#               count        mean         std     min       25%      50%  \
# Color
# Black          64.0  123.021250  281.435169    2.12    2.7925   19.595
# Blue           22.0   17.610909   12.447544    2.96    3.1100   25.550
# Grey            0.0         NaN         NaN     NaN       NaN      NaN
# Multi           0.0         NaN         NaN     NaN       NaN      NaN
# Red            37.0   10.173784    7.511641    2.12    2.3200   14.130
# Silver         34.0   40.579412   79.649904    2.68    2.8575   21.275
# Silver/Black    6.0  187.333333   26.673333  149.00  172.2500  187.000
# White           0.0         NaN         NaN     NaN       NaN      NaN
# Yellow         32.0   13.820625   10.751752    2.18    3.0350   15.950
#
#                    75%     max
# Color
# Black          25.8600  1050.0
# Blue           27.8450    30.0
# Grey               NaN     NaN
# Multi              NaN     NaN
# Red            17.1300    20.0
# Silver         27.4025   317.0
# ...

# %%
#changing data type
#Name is a object type
df.Name
# Out:
# 0            Adjustable Race
# 1               Bearing Ball
# 2            BB Ball Bearing
# 3      Headset Ball Bearings
# 4                      Blade
#                ...
# 499        ML Bottom Bracket
# 500        HL Bottom Bracket
# 501       Road-750 Black, 44
# 502       Road-750 Black, 48
# 503       Road-750 Black, 52
# Name: Name, Length: 504, dtype: object

# %%
#change type stored to as a string
#not sure what astype function is supposed to work as
###### df.Name.astype('str')

# %%
#value counts of color
df.Color.value_counts()
# Out:
# Black           93
# Silver          43
# Red             38
# Yellow          36
# Blue            26
# Multi            8
# Silver/Black     7
# White            4
# Grey             1
# Name: Color, dtype: int64

# %%
#basic plot of value couts of Color (default line)
df.Color.value_counts().plot()

# %%
#bar chart (vertical default)
df.Color.value_counts().plot(kind='bar')

# %%
#horizontal bar charts
df.Color.value_counts().plot(kind='barh')

# %%
#checking that parse dates worked
df.ModifiedDate
# Out:
# 0     2014-02-08 10:01:36.827
# 1     2014-02-08 10:01:36.827
# 2     2014-02-08 10:01:36.827
# 3     2014-02-08 10:01:36.827
# 4     2014-02-08 10:01:36.827
#                 ...
# 499   2014-02-08 10:01:36.827
# 500   2014-02-08 10:01:36.827
# 501   2014-02-08 10:01:36.827
# 502   2014-02-08 10:01:36.827
# 503   2014-02-08 10:01:36.827
# Name: ModifiedDate, Length: 504, dtype: datetime64[ns]

# %%
#Using dt function to show only date year instead of full date time
df.ModifiedDate.dt.year
# Out:
# 0      2014
# 1      2014
# 2      2014
# 3      2014
# 4      2014
#        ...
# 499    2014
# 500    2014
# 501    2014
# 502    2014
# 503    2014
# Name: ModifiedDate, Length: 504, dtype: int64

# %%
#Using dt function to show only date month instead of full date time
df.ModifiedDate.dt.month
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 499    2
# 500    2
# 501    2
# 502    2
# 503    2
# Name: ModifiedDate, Length: 504, dtype: int64

# %%
#Using dt function to show only date year instead of full date time
df.ModifiedDate.dt.dayofweek
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 499    5
# 500    5
# 501    5
# 502    5
# 503    5
# Name: ModifiedDate, Length: 504, dtype: int64
